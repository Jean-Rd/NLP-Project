# %%
import PyPDF2

# %%
pdf = open('Fisica de lo imposible - Michio Kaku.pdf', 'rb') # con rb le dijimos que lo abra en binary

# %%
PDF = PyPDF2.PdfFileReader(pdf)

# %%
PDF.isEncrypted
# Out:
# False

# %%
p = PDF.getPage(100)
p.extractText()
# Out:
# 'Física de lo imposible www.libros\nmaravillosos.com Michio Kaku \nColaboración de Sergio Barros 101 Preparado por Patricio Barros \nregiones del cerebro se podrían evocar imágenes y pensamientos visuales. Pero la \ninvestigación en esta dirección está solo en sus primeras etapas. \n\n \nCartografiando el cerebro \nAlgunos científicos han defen\ndido un «proyecto de cartografía neuronal», similar al \nProyecto Genoma Humano que hizo un mapa de todos los genes en el genoma \n\nhumano. Un proyecto de cartografía neuronal\n localizaría cada neurona individual en \nel cerebro humano y crearía un mapa en 3D que mostrara todas sus conexiones. \n\nSería un proyecto verdaderamente monumental, puesto que hay más de 100.000 \nmillones de neuronas en el cerebro y ca\nda neurona está conectada con otras miles \nde neuronas. Suponiendo que dicho proyecto se lleve a cabo, cabe pensar que sería \n\nposible representar cómo ciertos pensa\nmientos estimulan determinados caminos \nneurales. Combinado 
# ...

# %%
np.array()
# Out:
# 321

# %%
import numpy as np

# %%
pages = []

for i in range(0, PDF.numPages):
    page = PDF.getPage(i)
    pages.append(page.extractText())

# %%
pages
# Out:
# ['Física de lo imposible www.libros\nmaravillosos.com Michio Kaku \nColaboración de Sergio Barros 1 Preparado por Patricio Barros \n   ',
# ...
